# %%
# %matplotlib inline

import matplotlib.pyplot as plt

print("printing graph")

# to plot red dot use "ro", default blue line "b-", red line "r-"

plt.plot([10,20,20,30,50], [10,20,300,400,5000], "r-")
plt.ylabel("some y")
plt.xlabel("some x")
plt.show()
# Out:
# printing graph
